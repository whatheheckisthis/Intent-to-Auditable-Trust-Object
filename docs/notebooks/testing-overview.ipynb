# %% [markdown]
# # Test Operations Workbook\n\nDeployment-grade documentation for validating Python and C# test assemblies and AWS-backed API key loading.

# %% [markdown]
# ## Scope\n\n- `tests/python/` validates runtime metadata, AWS Secrets Manager API key retrieval, endpoint URL composition, and IAM risk scoring.\n- `tests/csharp/NfcReader.Tests/` validates stream behavior in the `NfcReader` assembly.

# %%
# Python validation\n!python -m unittest discover -s tests/python -p 'test_*.py'

# %%
# C# validation (requires .NET SDK)\n!dotnet test tests/csharp/NfcReader.Tests/NfcReader.Tests.csproj --configuration Release
