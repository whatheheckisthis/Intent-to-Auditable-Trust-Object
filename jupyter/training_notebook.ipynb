# %% [markdown]
# # Root Training Notebook
# Minimal notebook for testing FastAPI project utilities.

# %%
# Import local project code
import sys, os
sys.path.append(os.path.abspath("src"))

from kernel.entropy_pgd import pgd_optimize
from kernel.trust_objects import log_trust_object

# %%
# Quick test run
result = pgd_optimize(lambda x: (x - 2) ** 2, 0.0, {"learning_rate": 0.1, "num_steps": 25})
log_trust_object({"task": "notebook_test", "result": result})
print("Notebook training completed:", result)
