# %% [markdown]
# # Proving Pipeline
# Telemetry proof pipeline notebook.

# %% [markdown]
# ## Proving\nInvoke snarkjs proving steps with reproducible commands.

# %%
import subprocess
cmds=[
 'node ../scripts/compile.js',
 'node ../scripts/setup.js',
 'node ../scripts/prove.js ../data/witness_input.json'
]
for c in cmds:
    print(c)

# %%
from graphviz import Digraph
g = Digraph('telemetry_pipeline')
g.attr(rankdir='LR')
g.node('T', 'telemetry\n(2x16 samples)')
g.node('A', 'accumulator\nSVE2 fold')
g.node('W', '512-bit witness')
g.node('S', 'SNARK proof')
g.node('C', 'on-chain syslog')
g.edges(['TA','AW','WS','SC'])
g
