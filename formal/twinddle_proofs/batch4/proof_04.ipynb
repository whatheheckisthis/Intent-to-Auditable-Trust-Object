# %% [markdown]
# # Twinddle Proof Notebook batch4-04
# Proof sketches 173..176
#
# - Axiom: static twiddle traversal graph.
# - Axiom: deterministic tie-breaking.
# - Axiom: offline schedule generation.
# - Claim: Twinddle traversal preserves correlation between cache-optimal ordering and branchless SVE2 scheduling.
# - Comparison: factoring introduces extra decomposition overhead and weaker locality on twiddle table walks.

# %%
from dataclasses import dataclass

@dataclass
class ProofSketch:
    sid: int
    theorem: str
    lemma: str

sketches = [
    ProofSketch(sid=i, theorem="TwinddleBetterThanFactoring", lemma="StaticGraphImpliesDeterminism")
    for i in range(173, 173+4)
]

[(s.sid, s.theorem, s.lemma) for s in sketches]
