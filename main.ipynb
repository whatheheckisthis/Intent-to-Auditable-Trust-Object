# %% [markdown]
# # Root Notebook
# Quick check of FastAPI + PGD + Trust Objects

# %%
# !pip install -r requirements.txt

# %%
from src.kernel.entropy_pgd import pgd_optimize
from src.kernel.trust_objects import log_trust_object

result = pgd_optimize(lambda x: (x - 2) ** 2, 0.0, {"learning_rate": 0.1, "num_steps": 10})
log_trust_object({"from": "notebook_test", "result": result})
result
